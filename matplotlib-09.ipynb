# %% [markdown]
# # 09 - Matplotlib Style

# %% [markdown]
# # Import Modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.4
# 1.19.5

# %% [markdown]
# # Fungsi Plotting

# %% [markdown]
# disini akan membentuk barplot

# %%
def gambar_barplot():
    data1 = [25,85,75,40,60]
    data2 = [40,35,20,55,10]
    kategori = ['A','B','C','D','E']
    
    x = np.arange(len(kategori))
    width = 0.35
    
    plt.bar(x-width/2,data1,width,label='Data 1')
    plt.bar(x+width/2,data2,width,label='Data 2')
    
    plt.xticks(x,kategori)
    
    plt.grid(linestyle='--',linewidth=1,axis='y',alpha=0.75)
    
    plt.xlabel('kategori')
    plt.ylabel('jumlah')
    plt.title('Contoh groupe bar plot')
    
    plt.legend()
    plt.show()

# %%
gambar_barplot()

# %% [markdown]
# # Matplotlib Style

# %% [markdown]
# disini kita bisa melihat daftar syle apa aja yang ada

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# disini kita bisa mengubah style tersebut dengan menggunakan fungsi style.use dan disertai nama stylenya

# %%
style.use('ggplot')
gambar_barplot()

# %%
style.use('seaborn')
gambar_barplot()

# %%
style.use('seaborn-paper')
gambar_barplot()

# %%
style.use('grayscale')
gambar_barplot()
