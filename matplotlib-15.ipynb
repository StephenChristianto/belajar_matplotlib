# %% [markdown]
# # 15 - Belajar 3D Area Plot / 3D Area Chart

# %% [markdown]
# # Import Modules

# %%
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.4
# 1.20.1

# %% [markdown]
# # Sample Dataset

# %% [markdown]
# 1.membuat variabel dengan menggenerate sebuah angka yang nilai terendah -3 dan max nya 3 sebanyak 100 data

# %%
n = np.linspace(-3.0,3.0,100)

x,y = np.meshgrid(n,n)
z = np.sqrt(x**2+y**2)

print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# # 3D Wireframe

# %% [markdown]
# 1.memanggil plt.figure untuk membuat object figure
#
# 2.membuat object axes dengan menyertakan parameter projection bernilai 3d
#
# 3.memanggil fungsi ax.plot_wireframe

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_wireframe(x,y,z,color='orange')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Wireframe')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3D surface Plot

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x,y,z,color='orange')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Surface Plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
