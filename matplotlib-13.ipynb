# %% [markdown]
# # 13 - 3D Plot / 3D Chart

# %% [markdown]
# # Import Modules

# %%
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.4
# 1.20.1

# %% [markdown]
# # 3D Axes

# %% [markdown]
# 1.untuk membuat 3d axes kita harus membuat object figure
#
# 2.membentuk object axes dengan parameter projection dengan nilai 3d

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3D Line Plot

# %% [markdown]
# 1.membuat 3 variabel , untuk variabel z untuk menampung np.random dari jangkauan 0 sampai 1 sebanyak 100 data
#
# 2.variabel x nya hasil z dikali np.sin 20 dikali z
#
# 3.variabel y nya hasil z dikali np.cos 20 dikali z

# %%
z = np.linspace(0,1,100)
x = z * np.sin(20*z)
y = z * np.cos(20*z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(x,y,z,color='red')

ax.set(title='Contoh 3D line plot',xlabel = 'sumbu X',ylabel = 'sumbu Y',zlabel = 'sumbu Z')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Scatter plot

# %%
z = np.linspace(0,1,100)
x = z * np.sin(20*z)
y = z * np.cos(20*z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter(x,y,z,color='red')

ax.set(title='Contoh 3D Scatter Plot',xlabel = 'sumbu X',ylabel = 'sumbu Y',zlabel = 'sumbu Z')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
